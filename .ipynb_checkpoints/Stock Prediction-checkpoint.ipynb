# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,LSTM
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('GOOG.csv')

# %%
df.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
df.isnull().sum() #checking for any null values
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
print("date datatype - ",type(df['date'][0]))
# Out:
# date datatype -  <class 'str'>

# %%
print(df['date'][0])
# Out:
# 2016-06-14 00:00:00+00:00

# %%
df['date']=pd.to_datetime(df.date) #changing str to datetime

# %%
df['date']=df['date'].dt.date #removing time from date

# %%
print(df['date'][0])
# Out:
# 2016-06-14

# %%
df.head()
# Out:
#   symbol        date   close    high       low    open   volume  adjClose  \
# 0   GOOG  2016-06-14  718.27  722.47  713.1200  716.48  1306065    718.27
# 1   GOOG  2016-06-15  718.92  722.98  717.3100  719.00  1214517    718.92
# 2   GOOG  2016-06-16  710.36  716.65  703.2600  714.91  1982471    710.36
# 3   GOOG  2016-06-17  691.72  708.82  688.4515  708.65  3402357    691.72
# 4   GOOG  2016-06-20  693.71  702.48  693.4100  698.77  2082538    693.71
#
#    adjHigh    adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0   722.47  713.1200   716.48    1306065      0.0          1.0
# 1   722.98  717.3100   719.00    1214517      0.0          1.0
# 2   716.65  703.2600   714.91    1982471      0.0          1.0
# 3   708.82  688.4515   708.65    3402357      0.0          1.0
# 4   702.48  693.4100   698.77    2082538      0.0          1.0

# %%
df=df.drop(['symbol'],axis=1)
df.head()
# Out:
#          date   close    high       low    open   volume  adjClose  adjHigh  \
# 0  2016-06-14  718.27  722.47  713.1200  716.48  1306065    718.27   722.47
# 1  2016-06-15  718.92  722.98  717.3100  719.00  1214517    718.92   722.98
# 2  2016-06-16  710.36  716.65  703.2600  714.91  1982471    710.36   716.65
# 3  2016-06-17  691.72  708.82  688.4515  708.65  3402357    691.72   708.82
# 4  2016-06-20  693.71  702.48  693.4100  698.77  2082538    693.71   702.48
#
#      adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0  713.1200   716.48    1306065      0.0          1.0
# 1  717.3100   719.00    1214517      0.0          1.0
# 2  703.2600   714.91    1982471      0.0          1.0
# 3  688.4515   708.65    3402357      0.0          1.0
# 4  693.4100   698.77    2082538      0.0          1.0

# %%
df.set_index('date')
# Out:
#               close      high        low     open   volume  adjClose  \
# date
# 2016-06-14   718.27   722.470   713.1200   716.48  1306065    718.27
# 2016-06-15   718.92   722.980   717.3100   719.00  1214517    718.92
# 2016-06-16   710.36   716.650   703.2600   714.91  1982471    710.36
# 2016-06-17   691.72   708.820   688.4515   708.65  3402357    691.72
# 2016-06-20   693.71   702.480   693.4100   698.77  2082538    693.71
# ...             ...       ...        ...      ...      ...       ...
# 2021-06-07  2466.09  2468.000  2441.0725  2451.32  1192453   2466.09
# 2021-06-08  2482.85  2494.495  2468.2400  2479.90  1253253   2482.85
# 2021-06-09  2491.40  2505.000  2487.3300  2499.50  1006337   2491.40
# 2021-06-10  2521.60  2523.260  2494.0000  2494.01  1561733   2521.60
# 2021-06-11  2513.93  2526.990  2498.2900  2524.92  1262309   2513.93
#
#              adjHigh     adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2016-06-14   722.470   713.1200   716.48    1306065      0.0          1.0
# 2016-06-15   722.980   717.3100   719.00    1214517      0.0          1.0
# 2016-06-16   716.650   703.2600   714.91    1982471      0.0          1.0
# 2016-06-17   708.820   688.4515   708.65    3402357      0.0          1.0
# 2016-06-20   702.480   693.4100   698.77    2082538      0.0          1.0
# ...              ...        ...      ...        ...      ...          ...
# 2021-06-07  2468.000  2441.0725  2451.32    1192453      0.0          1.0
# 2021-06-08  2494.495  2468.2400  2479.90    1253253      0.0          1.0
# 2021-06-09  2505.000  2487.3300  2499.50    1006337      0.0          1.0
# 2021-06-10  2523.260  2494.0000  2494.01    1561733      0.0          1.0
# 2021-06-11  2526.990  2498.2900  2524.92    1262309      0.0          1.0
#
# [1258 rows x 12 columns]

# %%
df=df[-255:] #taking only one year stock
df.shape
# Out:
# (255, 13)

# %%
df.set_index('date')
df.head()
# Out:
#             date    close     high      low     open   volume  adjClose  \
# 1003  2020-06-09  1456.16  1468.00  1443.21  1445.36  1409249   1456.16
# 1004  2020-06-10  1465.85  1474.26  1456.27  1459.54  1525153   1465.85
# 1005  2020-06-11  1403.84  1454.47  1402.00  1442.48  1991332   1403.84
# 1006  2020-06-12  1413.18  1437.00  1386.02  1428.49  1946367   1413.18
# 1007  2020-06-15  1419.85  1424.80  1387.92  1390.80  1506096   1419.85
#
#       adjHigh   adjLow  adjOpen  adjVolume  divCash  splitFactor
# 1003  1468.00  1443.21  1445.36    1409249      0.0          1.0
# 1004  1474.26  1456.27  1459.54    1525153      0.0          1.0
# 1005  1454.47  1402.00  1442.48    1991332      0.0          1.0
# 1006  1437.00  1386.02  1428.49    1946367      0.0          1.0
# 1007  1424.80  1387.92  1390.80    1506096      0.0          1.0

# %%
plt.plot(df.date,df.open,label='open')

plt.title('Stock Opening prices')
plt.xlabel('date')
plt.ylabel('price')

plt.legend()
plt.show()

# %%
plt.plot(df.date,df.close,label='close',color='red')

plt.title('Stock closing prices')
plt.xlabel('date')
plt.ylabel('price')

plt.legend()
plt.show()

# %%
# separating required data for model
data=df[['date','open','close']]
data.head()
# Out:
#             date     open    close
# 1003  2020-06-09  1445.36  1456.16
# 1004  2020-06-10  1459.54  1465.85
# 1005  2020-06-11  1442.48  1403.84
# 1006  2020-06-12  1428.49  1413.18
# 1007  2020-06-15  1390.80  1419.85

# %%
#resetting index
data=data.reset_index()
# data=data.drop('index',axis=1)
data.head()
# Out:
#    index        date     open    close
# 0   1003  2020-06-09  1445.36  1456.16
# 1   1004  2020-06-10  1459.54  1465.85
# 2   1005  2020-06-11  1442.48  1403.84
# 3   1006  2020-06-12  1428.49  1413.18
# 4   1007  2020-06-15  1390.80  1419.85

# %%
plt.plot(data.date,data.close,label='close',color='red')

plt.title('Stock closing prices')
plt.xlabel('date')
plt.ylabel('price')

plt.legend()
plt.show()

# %%
#Preprocessing data
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(data['close'].values.reshape(-1,1))

# %%
data.shape
# Out:
# (255, 4)

# %%
prediction_days=100

# %%
x_train=[]
y_train=[]

# %%
#preparing dpendent and independent values
for i in range(prediction_days,len(scaled_data)):
    x_train.append(scaled_data[i-prediction_days:i])
    y_train.append(scaled_data[i])

# %%
x_train[0]
# Out:
# array([[0.08286132],
#        [0.09120255],
#        [0.03782388],
#        [0.04586382],
#        [0.05160541],
#        [0.07129207],
#        [0.07852285],
#        [0.06547301],
#        [0.06182319],
#        [0.07915985],
#        [0.08996299],
#        [0.06203839],
#        [0.07009555],
#        [0.        ],
#        [0.03018852],
#        [0.04623397],
#        [0.06726349],
#        [0.09021262],
#        [0.11689765],
#        [0.10784196],
#        [0.11715589],
#        [0.1300594 ],
#        [0.15652922],
#        [0.13036068],
#        [0.13831454],
#        [0.13234054],
#        [0.13609366],
#        [0.13398468],
#        [0.17717139],
#        [0.17088749],
#        [0.17955582],
#        [0.13409658],
#        [0.13081691],
#        [0.14659551],
#        [0.1208918 ],
#        [0.1395541 ],
#        [0.14767152],
#        [0.10593096],
#        [0.09860549],
#        [0.09044504],
#        [0.09788241],
#        [0.1206852 ],
#        [0.11585607],
#        [0.11724197],
#        [0.10365843],
#        [0.12629767],
#        [0.13648102],
#        [0.12725316],
#        [0.13607644],
#        [0.17104244],
#        [0.1615133 ],
#        [0.19097013],
#        [0.18982526],
#        [0.19652234],
#        [0.2137557 ],
#        [0.25176896],
#        [0.23623139],
#        [0.24490832],
#        [0.23610226],
#        [0.25893949],
#        [0.31710424],
#        [0.24269605],
#        [0.19896703],
#        [0.14848067],
#        [0.16963071],
#        [0.14816218],
#        [0.13843505],
#        [0.13719549],
#        [0.15627098],
#        [0.13859   ],
#        [0.11675131],
#        [0.08615822],
#        [0.06134114],
#        [0.09086683],
#        [0.04761126],
#        [0.05887062],
#        [0.07322028],
#        [0.09005767],
#        [0.09419816],
#        [0.09443058],
#        [0.11206852],
#        [0.08480675],
#        [0.10856503],
#        [0.08051993],
#        [0.08641646],
#        [0.10848756],
#        [0.13370061],
#        [0.18012396],
#        [0.1823018 ],
#        [0.17920289],
#        [0.17149867],
#        [0.18344667],
#        [0.15039167],
#        [0.16874408],
#        [0.20092106],
#        [0.21987604],
#        [0.24197297],
#        [0.19845915],
#        [0.21034691],
#        [0.13490574]])

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)

# %%
#adding one additional dimension
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
x_train[0]
# Out:
# array([[0.08286132],
#        [0.09120255],
#        [0.03782388],
#        [0.04586382],
#        [0.05160541],
#        [0.07129207],
#        [0.07852285],
#        [0.06547301],
#        [0.06182319],
#        [0.07915985],
#        [0.08996299],
#        [0.06203839],
#        [0.07009555],
#        [0.        ],
#        [0.03018852],
#        [0.04623397],
#        [0.06726349],
#        [0.09021262],
#        [0.11689765],
#        [0.10784196],
#        [0.11715589],
#        [0.1300594 ],
#        [0.15652922],
#        [0.13036068],
#        [0.13831454],
#        [0.13234054],
#        [0.13609366],
#        [0.13398468],
#        [0.17717139],
#        [0.17088749],
#        [0.17955582],
#        [0.13409658],
#        [0.13081691],
#        [0.14659551],
#        [0.1208918 ],
#        [0.1395541 ],
#        [0.14767152],
#        [0.10593096],
#        [0.09860549],
#        [0.09044504],
#        [0.09788241],
#        [0.1206852 ],
#        [0.11585607],
#        [0.11724197],
#        [0.10365843],
#        [0.12629767],
#        [0.13648102],
#        [0.12725316],
#        [0.13607644],
#        [0.17104244],
#        [0.1615133 ],
#        [0.19097013],
#        [0.18982526],
#        [0.19652234],
#        [0.2137557 ],
#        [0.25176896],
#        [0.23623139],
#        [0.24490832],
#        [0.23610226],
#        [0.25893949],
#        [0.31710424],
#        [0.24269605],
#        [0.19896703],
#        [0.14848067],
#        [0.16963071],
#        [0.14816218],
#        [0.13843505],
#        [0.13719549],
#        [0.15627098],
#        [0.13859   ],
#        [0.11675131],
#        [0.08615822],
#        [0.06134114],
#        [0.09086683],
#        [0.04761126],
#        [0.05887062],
#        [0.07322028],
#        [0.09005767],
#        [0.09419816],
#        [0.09443058],
#        [0.11206852],
#        [0.08480675],
#        [0.10856503],
#        [0.08051993],
#        [0.08641646],
#        [0.10848756],
#        [0.13370061],
#        [0.18012396],
#        [0.1823018 ],
#        [0.17920289],
#        [0.17149867],
#        [0.18344667],
#        [0.15039167],
#        [0.16874408],
#        [0.20092106],
#        [0.21987604],
#        [0.24197297],
#        [0.19845915],
#        [0.21034691],
#        [0.13490574]])

# %%
#spliting data in train and test
X_train,X_test,Y_train,Y_test=train_test_split(x_train,y_train,random_state=0,shuffle=False)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (116, 100, 1)
# (39, 100, 1)

# %%
#building the model
model=Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
# model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
# model.add(Dropout(0.2))

model.add(Dense(units=1,activation='softmax')) #prediction layer

model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 100, 50)           10400
#
#  dropout_21 (Dropout)        (None, 100, 50)           0
#
#  dropout_22 (Dropout)        (None, 100, 50)           0
#
#  lstm_23 (LSTM)              (None, 50)                20200
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
#training
model.fit(X_train,Y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 8s 86ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 2/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 3/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 4/20
# 4/4 [==============================] - 0s 80ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 5/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 6/20
# 4/4 [==============================] - 0s 89ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 7/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 8/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 9/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 10/20
# 4/4 [==============================] - 0s 79ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 11/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 12/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 13/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 14/20
# 4/4 [==============================] - 0s 79ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 15/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 16/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 17/20
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 18/20
# 4/4 [==============================] - 0s 81ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 19/20
# 4/4 [==============================] - 0s 88ms/step - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 20/20
# 4/4 [==============================] - 0s 87ms/step - loss: 0.2909 - accuracy: 0.0000e+00
